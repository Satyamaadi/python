# %% [markdown]
# <a href="https://colab.research.google.com/github/Satyamaadi/python/blob/master/TextRepresentationDoc2Vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
documents = ["Dog bites man.", "Man bites dog.", "Dog eats meat.", "Man eats food."]
processed_docs = [doc.lower().replace(".","") for doc in documents]
processed_docs
# Out:
# ['dog bites man', 'man bites dog', 'dog eats meat', 'man eats food']

# %%
for sent in processed_docs:
  sent_nlp = nlp(sent)
  for token in sent_nlp:
    print(token.text,token.vector)
# Out:
# dog [ 1.6165221  -0.60930157  0.0275037   0.10335092  0.27418151 -0.48431718
#   0.12260848  0.38948804  0.6679814  -0.05190766 -0.09937462  0.45653057
#   0.24994741 -0.56699383 -1.0050936  -1.0017856   0.30296656 -0.09855372
#  -0.51928836 -0.6364862   0.6068408   0.8861691   0.1979292   0.144762
#   1.860283    0.00734958  0.12825397  0.27227488 -0.29297602 -0.36119652
#   1.4165466  -1.2333598  -0.885733   -0.41754887  0.1409666  -1.0910527
#  -0.4903083   0.4600508  -0.67008424 -1.0129143  -0.8661849   0.6114386
#  -1.0628924  -0.51779115 -0.50866467 -0.01524495  1.2248592  -1.3768485
#   1.1650462   0.12154715 -1.1988373   0.5650939  -0.579047   -0.42219913
#  -0.3997001   0.75756824  1.179214    0.36347824  0.01604678  0.1918616
#  -1.5152694  -0.3295007   0.3138316   0.16254054 -0.8980956  -0.46109518
#   0.8037902  -0.36612743  0.5920938  -0.8979591   1.9278831   0.15152426
#  -0.63551915 -0.33571666 -0.08411168  1.7697809  -0.48196176  0.6279967
# ...
