# %% [markdown]
# <a href="https://colab.research.google.com/github/Satyamaadi/python/blob/master/OpenCV_app3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
# !wget https://raw.githubusercontent.com/Apress/building-computer-vision-apps-artificial-neural-networks/master/chapter2/images/marsrover.png
# Out:
# --2021-02-06 05:48:52--  https://raw.githubusercontent.com/Apress/building-computer-vision-apps-artificial-neural-networks/master/chapter2/images/marsrover.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 384870 (376K) [image/png]
# Saving to: ‘marsrover.png’
#
# marsrover.png       100%[===================>] 375.85K  --.-KB/s    in 0.04s
#
# 2021-02-06 05:48:52 (8.86 MB/s) - ‘marsrover.png’ saved [384870/384870]

# %%
image = cv2.imread('marsrover.png')

# %%
start=(0,0)

# %%
end = (image.shape[1],image.shape[0])

# %%
color=(255,0,0)

# %%
thickness=4

# %%
cv2.line(image,start,end,color,thickness)
# Out:
# array([[[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [ 46,  91, 255],
#         [ 46,  91, 255],
#         [ 46,  91, 255]],
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [ 46,  91, 255],
#         [ 46,  91, 255],
#         [ 46,  91, 255]],
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [ 46,  91, 255],
#         [ 46,  91, 255],
#         [ 46,  91, 255]],
#
#        ...,
#
#        [[ 11,  29, 136],
#         [ 12,  30, 137],
#         [ 12,  30, 137],
#         ...,
#         [255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0]],
#
#        [[  8,  28, 135],
#         [  9,  29, 136],
#         [ 10,  30, 137],
#         ...,
#         [255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0]],
#
#        [[ 10,  30, 137],
#         [ 10,  30, 137],
#         [ 11,  31, 138],
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(image)
