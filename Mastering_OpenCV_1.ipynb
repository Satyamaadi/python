# %% [markdown]
# <a href="https://colab.research.google.com/github/Satyamaadi/python/blob/master/Mastering_OpenCV_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
# !wget https://cdn.pixabay.com/photo/2015/04/23/22/00/tree-736885_960_720.jpg
# Out:
# --2021-01-22 05:41:56--  https://cdn.pixabay.com/photo/2015/04/23/22/00/tree-736885_960_720.jpg
# Resolving cdn.pixabay.com (cdn.pixabay.com)... 104.18.20.183, 104.18.21.183, 2606:4700::6812:14b7, ...
# Connecting to cdn.pixabay.com (cdn.pixabay.com)|104.18.20.183|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 90402 (88K) [image/jpeg]
# Saving to: ‘tree-736885_960_720.jpg.1’
#
# tree-736885_960_720 100%[===================>]  88.28K  --.-KB/s    in 0.004s
#
# 2021-01-22 05:41:56 (21.6 MB/s) - ‘tree-736885_960_720.jpg.1’ saved [90402/90402]

# %%
image = cv2.imread('tree-736885_960_720.jpg',cv2.IMREAD_COLOR)

# %%
type(image) #checking if image has been loaded
# Out:
# numpy.ndarray

# %%
dimensions = image.shape

# %%
dimensions
# Out:
# (597, 960, 3)

# %%
(h,w,d) = image.shape

# %%
print('Height:{},width:{},depth:{}'.format(h,w,d))
# Out:
# Height:597,width:960,depth:3

# %%
total_no_pixels = image.size

# %%
print(total_no_pixels)
# Out:
# 1719360

# %%
from IPython.display import Image
Image('tree-736885_960_720.jpg')

# %%
top_left_corner = image[0:50,0:50]

# %%
import matplotlib.pyplot as plt
plt.imshow(top_left_corner)
plt.axis('off')
# Out:
# (-0.5, 49.5, 49.5, -0.5)

# %%
image[0:50,0:50] = (255,0,0) #setting top left corner to red

# %%
plt.imshow(image)
