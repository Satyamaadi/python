# %% [markdown]
# <a href="https://colab.research.google.com/github/Satyamaadi/python/blob/master/OpenCV_app1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import print_function
import cv2

# %%
# !wget https://raw.githubusercontent.com/Apress/building-computer-vision-apps-artificial-neural-networks/master/chapter2/images/marsrover.png
# Out:
# --2021-02-06 05:21:22--  https://raw.githubusercontent.com/Apress/building-computer-vision-apps-artificial-neural-networks/master/chapter2/images/marsrover.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 384870 (376K) [image/png]
# Saving to: ‘marsrover.png’
#
# marsrover.png       100%[===================>] 375.85K  --.-KB/s    in 0.04s
#
# 2021-02-06 05:21:22 (8.89 MB/s) - ‘marsrover.png’ saved [384870/384870]

# %%
image = cv2.imread('marsrover.png')

# %%
type(image)
# Out:
# numpy.ndarray

# %%
print('Dimension  of image:',image.ndim)
print('Image height:',image.shape[0])
print('Image width:',image.shape[1])
print('Image channels:',image.shape[2])
print('Size of image:',image.size)
# Out:
# Dimension  of image: 3
# Image height: 400
# Image width: 640
# Image channels: 3
# Size of image: 768000

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(image)
