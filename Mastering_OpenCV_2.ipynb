# %% [markdown]
# <a href="https://colab.research.google.com/github/Satyamaadi/python/blob/master/Mastering_OpenCV_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
# !wget https://cdn.pixabay.com/photo/2015/04/23/22/00/tree-736885__340.jpg
# Out:
# --2021-01-22 05:55:00--  https://cdn.pixabay.com/photo/2015/04/23/22/00/tree-736885__340.jpg
# Resolving cdn.pixabay.com (cdn.pixabay.com)... 104.18.20.183, 104.18.21.183, 2606:4700::6812:14b7, ...
# Connecting to cdn.pixabay.com (cdn.pixabay.com)|104.18.20.183|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 32841 (32K) [image/jpeg]
# Saving to: ‘tree-736885__340.jpg’
#
# tree-736885__340.jp 100%[===================>]  32.07K  --.-KB/s    in 0s
#
# 2021-01-22 05:55:00 (102 MB/s) - ‘tree-736885__340.jpg’ saved [32841/32841]

# %%
image = cv2.imread('tree-736885__340.jpg',cv2.IMREAD_GRAYSCALE)

# %%
dimension = image.shape

# %%
print(dimension)
# Out:
# (340, 546)

# %%
(h,w) = image.shape

# %%
print('Total pixels:',image.size)
# Out:
# Total pixels: 185640

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(image)

# %%
top_left = image[0:50,0:50]

# %%
plt.imshow(top_left)
