# %% [markdown]
# <a href="https://colab.research.google.com/github/Satyamaadi/python/blob/master/Mastering_OpenCV_image_display.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# !wget https://cdn.pixabay.com/photo/2015/04/23/22/00/tree-736885__340.jpg
# Out:
# --2021-01-22 06:01:55--  https://cdn.pixabay.com/photo/2015/04/23/22/00/tree-736885__340.jpg
# Resolving cdn.pixabay.com (cdn.pixabay.com)... 104.18.21.183, 104.18.20.183, 2606:4700::6812:15b7, ...
# Connecting to cdn.pixabay.com (cdn.pixabay.com)|104.18.21.183|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 32841 (32K) [image/jpeg]
# Saving to: ‘tree-736885__340.jpg’
#
# tree-736885__340.jp 100%[===================>]  32.07K  --.-KB/s    in 0s
#
# 2021-01-22 06:01:55 (97.1 MB/s) - ‘tree-736885__340.jpg’ saved [32841/32841]

# %%
image = cv2.imread('tree-736885__340.jpg')

# %%
plt.imshow(image)

# %%
b,g,r = cv2.split(image)

# %%
import numpy as np
imd_concat = np.concatenate((image,image),axis=0)

# %%
plt.imshow(imd_concat)
