# %% [markdown]
# <a href="https://colab.research.google.com/github/Satyamaadi/python/blob/master/OpenCV_app2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
# !wget https://raw.githubusercontent.com/Apress/building-computer-vision-apps-artificial-neural-networks/master/chapter2/images/marsrover.png
# Out:
# --2021-02-06 05:27:37--  https://raw.githubusercontent.com/Apress/building-computer-vision-apps-artificial-neural-networks/master/chapter2/images/marsrover.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 384870 (376K) [image/png]
# Saving to: ‘marsrover.png’
#
# marsrover.png       100%[===================>] 375.85K  --.-KB/s    in 0.04s
#
# 2021-02-06 05:27:37 (8.77 MB/s) - ‘marsrover.png’ saved [384870/384870]

# %%
image = cv2.imread('marsrover.png')

# %%
(b,g,r) = image[0,0]

# %%
print('B,G,R values at 0,0:',format((b,g,r)))
# Out:
# B,G,R values at 0,0: (40, 55, 134)

# %%
image[0:100,0:100] = (255,255,0)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(image)
