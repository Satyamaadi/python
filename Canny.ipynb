# %% [markdown]
# <a href="https://colab.research.google.com/github/Satyamaadi/python/blob/master/Canny.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np

# %%
# !wget https://tinyjpg.com/images/social/website.jpg
# Out:
# --2021-01-29 05:12:14--  https://tinyjpg.com/images/social/website.jpg
# Resolving tinyjpg.com (tinyjpg.com)... 35.190.0.251
# Connecting to tinyjpg.com (tinyjpg.com)|35.190.0.251|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 124814 (122K) [image/jpeg]
# Saving to: ‘website.jpg’
#
# website.jpg         100%[===================>] 121.89K  --.-KB/s    in 0.002s
#
# 2021-01-29 05:12:14 (54.0 MB/s) - ‘website.jpg’ saved [124814/124814]

# %%
image = cv2.imread('website.jpg')

# %%
type(image)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('canny.jpg',cv2.Canny(image,200,300))
# Out:
# True

# %%
import matplotlib.pyplot as plt

# %%
image2 = cv2.imread('canny.jpg',cv2.IMREAD_COLOR)

# %%
plt.imshow(image2)

# %%
from PIL import Image

# %%
im = Image.open('canny.jpg')

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1020x510 at 0x7F7844A48320>
