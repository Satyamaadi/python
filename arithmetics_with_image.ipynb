# %% [markdown]
# <a href="https://colab.research.google.com/github/Satyamaadi/python/blob/master/arithmetics_with_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
def show_with_matplotlib(color_img, title, pos):
    """Shows an image using matplotlib capabilities"""

    # Convert BGR image to RGB:
    img_RGB = color_img[:, :, ::-1]

    ax = plt.subplot(2, 3, pos)
    plt.imshow(img_RGB)
    plt.title(title)
    plt.axis('off')

# %%
# !wget https://www.talkwalker.com/images/2020/blog-headers/image-analysis.png
# Out:
# --2021-01-22 09:36:41--  https://www.talkwalker.com/images/2020/blog-headers/image-analysis.png
# Resolving www.talkwalker.com (www.talkwalker.com)... 68.70.205.2, 68.70.205.1, 68.70.205.4, ...
# Connecting to www.talkwalker.com (www.talkwalker.com)|68.70.205.2|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 687535 (671K) [image/png]
# Saving to: ‘image-analysis.png’
#
# image-analysis.png  100%[===================>] 671.42K  --.-KB/s    in 0.1s
#
# 2021-01-22 09:36:41 (6.64 MB/s) - ‘image-analysis.png’ saved [687535/687535]

# %%
plt.figure(figsize=(12, 6))
plt.suptitle("Arithmetic with images", fontsize=14, fontweight='bold')
# Out:
# Text(0.5, 0.98, 'Arithmetic with images')

# %%
image = cv2.imread('image-analysis.png')

# %%
M = np.ones(image.shape, dtype="uint8") * 60
added_image = cv2.add(image, M)

# %%
subtracted_image = cv2.subtract(image, M)

# %%
scalar = np.ones((1, 3), dtype="float") * 110
added_image_2 = cv2.add(image, scalar)
subtracted_image_2 = cv2.subtract(image, scalar)

# %%
show_with_matplotlib(image, "image", 1)
show_with_matplotlib(added_image, "added 60 (image + image)", 2)
show_with_matplotlib(subtracted_image, "subtracted 60 (image - images)", 3)
show_with_matplotlib(added_image_2, "added 110 (image + scalar)", 5)
show_with_matplotlib(subtracted_image_2, "subtracted 110 (image - scalar)", 6)
