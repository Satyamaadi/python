# %% [markdown]
# <a href="https://colab.research.google.com/github/Satyamaadi/python/blob/master/Frontal_Face_Reckon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://github.com/PacktPublishing/Learning-OpenCV-4-Computer-Vision-with-Python-Third-Edition/blob/master/chapter05/cascades/haarcascade_frontalface_default.xml
# Out:
# --2021-02-03 05:33:29--  https://github.com/PacktPublishing/Learning-OpenCV-4-Computer-Vision-with-Python-Third-Edition/blob/master/chapter05/cascades/haarcascade_frontalface_default.xml
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘haarcascade_frontalface_default.xml’
#
# haarcascade_frontal     [ <=>                ]   8.25M  --.-KB/s    in 0.1s
#
# 2021-02-03 05:33:31 (84.3 MB/s) - ‘haarcascade_frontalface_default.xml’ saved [8653498]

# %%
import cv2
import matplotlib.pyplot as plt

# %%
!
# Out:
# haarcascade_frontalface_default.xml  sample_data

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

# %%
# !wget https://raw.githubusercontent.com/PacktPublishing/Learning-OpenCV-4-Computer-Vision-with-Python-Third-Edition/master/images/woodcutters.jpg
# Out:
# --2021-02-03 05:40:48--  https://raw.githubusercontent.com/PacktPublishing/Learning-OpenCV-4-Computer-Vision-with-Python-Third-Edition/master/images/woodcutters.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 288724 (282K) [image/jpeg]
# Saving to: ‘woodcutters.jpg’
#
# woodcutters.jpg     100%[===================>] 281.96K  --.-KB/s    in 0.03s
#
# 2021-02-03 05:40:49 (10.8 MB/s) - ‘woodcutters.jpg’ saved [288724/288724]

# %%
image = cv2.imread('woodcutters.jpg')

# %%
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %%
faces = face_cascade.detectMultiScale(gray, 1.08, 5)

# %%
for (x, y, w, h) in faces:
    image = cv2.rectangle(image, (x, y), (x+w, y+h), (255, 0, 0), 2)

# %%
cv2.imwrite('detected.jpg',image)
# Out:
# True

# %%
image_detect = cv2.imread('detected.jpg')

# %%
type(image_detect)
# Out:
# numpy.ndarray

# %%
plt.imshow(image_detect)
