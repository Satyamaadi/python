# %% [markdown]
# <a href="https://colab.research.google.com/github/Satyamaadi/python/blob/master/OpenCV_app1_day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# !wget https://raw.githubusercontent.com/Apress/building-computer-vision-apps-artificial-neural-networks/master/chapter3/images/zebrasmall.png
# Out:
# --2021-02-09 05:24:47--  https://raw.githubusercontent.com/Apress/building-computer-vision-apps-artificial-neural-networks/master/chapter3/images/zebrasmall.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 116937 (114K) [image/png]
# Saving to: ‘zebrasmall.png’
#
# zebrasmall.png      100%[===================>] 114.20K  --.-KB/s    in 0.03s
#
# 2021-02-09 05:24:47 (4.31 MB/s) - ‘zebrasmall.png’ saved [116937/116937]

# %%
image = cv2.imread('zebrasmall.png')

# %%
type(image)
# Out:
# numpy.ndarray

# %%
flipped_horizontal = cv2.flip(image,1)

# %%
plt.imshow(image)

# %%
plt.imshow(flipped_horizontal)

# %%
flipped_vertical = cv2.flip(image,0)

# %%
plt.imshow(flipped_vertical)

# %%
flipped_h_then_v = cv2.flip(image,-1)

# %%
plt.imshow(flipped_h_then_v)
